# %% [markdown]
# # VISUALIZING OUR DATA

# %%
#bringing in our package
import pandas as pd

# %%
#save dataframe in variable. So we'll name the variable 'df'
df = pd.read_csv("C:/Users/PEN BUSINESS ANALYST/Documents/Python for Power BI Users/Python+for+Power+BI+Users+-+Resource+Pack/HR_file.csv")

# %%
#We're going to import matplotlib and an object within it called pyplot and save it as plt.
import matplotlib.pyplot as plt

# %%
#We're also going to import seaborn and save as a variable called sns
import seaborn as sns

# %%
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Departments  \
# 0                   3              0     1                      0       sales
# 1                   6              0     1                      0       sales
# 2                   4              0     1                      0       sales
# 3                   5              0     1                      0       sales
# 4                   3              0     1                      0       sales
#
#    salary
# 0     low
# 1  medium
# ...

# %%
df.tail()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 14994                   151                   3              0     1
# 14995                   160                   3              0     1
# 14996                   143                   3              0     1
# 14997                   280                   4              0     1
# 14998                   158                   3              0     1
#
#        promotion_last_5years Departments salary
# 14994                      0     support    low
# 14995                      0     support    low
# ...

# %%
df.tail(20)
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 14979                0.09             0.93               6
# 14980                0.76             0.89               5
# 14981                0.73             0.93               5
# 14982                0.38             0.49               2
# 14983                0.72             0.84               5
# 14984                0.40             0.56               2
# 14985                0.91             0.99               5
# 14986                0.85             0.85               4
# 14987                0.90             0.70               5
# 14988                0.46             0.55               2
# 14989                0.43             0.57               2
# 14990                0.89             0.88               5
# 14991                0.09             0.81               6
# 14992                0.40             0.48               2
# 14993                0.76             0.83               6
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   Departments            14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %%
df.describe().T
# Out:
#                          count        mean        std    min     25%     50%  \
# satisfaction_level     14999.0    0.612834   0.248631   0.09    0.44    0.64
# last_evaluation        14999.0    0.716102   0.171169   0.36    0.56    0.72
# number_project         14999.0    3.803054   1.232592   2.00    3.00    4.00
# average_montly_hours   14999.0  201.050337  49.943099  96.00  156.00  200.00
# time_spend_company     14999.0    3.498233   1.460136   2.00    3.00    3.00
# Work_accident          14999.0    0.144610   0.351719   0.00    0.00    0.00
# left                   14999.0    0.238083   0.425924   0.00    0.00    0.00
# promotion_last_5years  14999.0    0.021268   0.144281   0.00    0.00    0.00
#
#                           75%    max
# satisfaction_level       0.82    1.0
# last_evaluation          0.87    1.0
# number_project           5.00    7.0
# average_montly_hours   245.00  310.0
# time_spend_company       4.00   10.0
# Work_accident            0.00    1.0
# ...

# %%
df.corr()
# Out:
#                        satisfaction_level  last_evaluation  number_project  \
# satisfaction_level               1.000000         0.105021       -0.142970
# last_evaluation                  0.105021         1.000000        0.349333
# number_project                  -0.142970         0.349333        1.000000
# average_montly_hours            -0.020048         0.339742        0.417211
# time_spend_company              -0.100866         0.131591        0.196786
# Work_accident                    0.058697        -0.007104       -0.004741
# left                            -0.388375         0.006567        0.023787
# promotion_last_5years            0.025605        -0.008684       -0.006064
#
#                        average_montly_hours  time_spend_company  \
# satisfaction_level                -0.020048           -0.100866
# last_evaluation                    0.339742            0.131591
# number_project                     0.417211            0.196786
# ...

# %%
df.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'Departments', 'salary'],
#       dtype='object')

# %%
df['number_project']
# Out:
# 0        2
# 1        5
# 2        7
# 3        5
# 4        2
#         ..
# 14994    2
# 14995    2
# 14996    2
# 14997    6
# 14998    2
# Name: number_project, Length: 14999, dtype: int64

# %%
df['number_project'].head()
# Out:
# 0    2
# 1    5
# 2    7
# 3    5
# 4    2
# Name: number_project, dtype: int64

# %%
df['number_project'].max()
# Out:
# 7

# %%
df['number_project'].min()
# Out:
# 2

# %%
#Now let's use Matplotlib. It's a really easy to use function, and you don't need to do a lot to get the function to work.

# %%
#One more dataframe variable that we're going to talk about is called GROUP BY and it's similar to a pivot table. 

#When conducting an analysis, you're usually conducting a univariate analysis (one variable), bivariate analysis (two variables), or multivariate analysis (multiple variables).

# %% [markdown]
# # Data Visualization
#
# - Univariate
# - Bivariate
# - Multivariate Analysis

# %%
# Which department has the most churn?
df.dtypes
# Out:
# satisfaction_level       float64
# last_evaluation          float64
# number_project             int64
# average_montly_hours       int64
# time_spend_company         int64
# Work_accident              int64
# left                       int64
# promotion_last_5years      int64
# Departments               object
# salary                    object
# dtype: object

# %%
# We usually want to group things with strings.
# ...so we want to group by department, or salary. (I (Jerry), guess the instructor specivided salary and dept because they have object dtypes.)

# %%
df.groupby('Departments')['left'].sum()
# Out:
# Departments
# IT              273
# RandD           121
# accounting      204
# hr              215
# management       91
# marketing       203
# product_mng     198
# sales          1014
# support         555
# technical       697
# Name: left, dtype: int64

# %%
#So now we have an index here and a value. This makes things very easy to plot.

# %%
df.groupby('Departments')['left'].sum().plot()
# Out:
# <AxesSubplot:xlabel='Departments'>

# %%
#So we see that the native visual is a line chart, but we can change the chart.

# %%
df.groupby('Departments')['left'].sum().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='left'>

# %%
df.groupby('Departments')['left'].sum().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Departments'>

# %%
df.groupby('Departments')['left'].sum().plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='Departments'>

# %%
#Remember the name of the variable we assigned or saved matplotlib to is plt.
#So, with that variable, we can modify the size of the figure - the figure is the same as the diagram. 

#So in the following order, we have (x,y)

# %%
plt.figure(figsize=(10,5))

df.groupby('Departments')['left'].sum().plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='Departments'>

# %%
#Notice the difference in the size of the figure.

# %%
#We can even make the style of figure more interesting.

# %%
plt.style.use('ggplot')

plt.figure(figsize=(10,5))

df.groupby('Departments')['left'].sum().plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='Departments'>

# %%
#Well, let's just go down and get a scatterplot.

# %% [markdown]
# # BiVariate Visuals

# %%
plt.scatter(df['satisfaction_level'],df['satisfaction_level'])
plt.savefig("BivariateAnalysisDataTrend.png")

# %%
plt.figure(figsize=(8,5))

plt.scatter(df['satisfaction_level'],df['last_evaluation'], c="blue", marker = '*')

plt.title("Bivariate Analysis: Satisfaction vs Evaluation")

plt.savefig("Correlation.png")

# %%
#Remember that we have Seaborn, so let's start looking at that. 
#Seaborn is much more statistical. 

#Maybe the first plot that we're going to look at is a distribution plot, which could be a histogram right? Yea, so...

# %%
sns.distplot(df['satisfaction_level'])
# Out:
# C:\Users\PEN BUSINESS ANALYST\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='satisfaction_level', ylabel='Density'>

# %%
#Notice we had what appeared at first to look like an error, but eventually upon close observation, isn't really an error. 
#This is a 'warning' - about sth that will happen.

#Is there a way we could handle this?

#Yea, we need to import sth we should have imported at the top 
#...when we imported Seaborn, Pandas and Matplotlib.


#So let's see it.

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sns.distplot(df['satisfaction_level'])
# Out:
# <AxesSubplot:xlabel='satisfaction_level', ylabel='Density'>

# %%
#Matlplot libraries work very well, hand-in-hand with Seaborn.

#So, we can modify the size of the distribution figure using the matplot figsize function, as shown or seen below:

# %%
plt.figure(figsize=(8,5))

sns.distplot(df['satisfaction_level'])
# Out:
# <AxesSubplot:xlabel='satisfaction_level', ylabel='Density'>

# %%
#How about a box plot? Let's see. Didn't really care, but instructor did. So we'll see boxplot.

# %%
plt.figure(figsize=(8,5))

sns.boxplot(df['satisfaction_level'])
# Out:
# <AxesSubplot:xlabel='satisfaction_level'>

# %%
#To see a vertical alignment of the figure, we assign the visual to 'y', instead of x, which appears to be the default orientation.

# %%
plt.figure(figsize=(8,5))

sns.boxplot(y =df['satisfaction_level'])
# Out:
# <AxesSubplot:ylabel='satisfaction_level'>

# %%
plt.figure(figsize=(8,5))

sns.boxenplot(y =df['satisfaction_level'])
# Out:
# <AxesSubplot:ylabel='satisfaction_level'>

# %%
plt.figure(figsize=(8,5))

sns.boxplot(x =df['Departments'], y =df['satisfaction_level'])
# Out:
# <AxesSubplot:xlabel='Departments', ylabel='satisfaction_level'>

# %%
#So let's see the correlation between the datapoints in our dataframe.

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
#So now we have a correlation plot. We can style this.

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.corr(),annot=True, linewidths = 0.5)
# Out:
# <AxesSubplot:>

# %%
#So the instructor wanted to look at sth he called a violin plot. From line 56.

# %%
plt.figure(figsize=(8,5))

sns.violinplot(x =df['Departments'], y =df['satisfaction_level'])
# Out:
# <AxesSubplot:xlabel='Departments', ylabel='satisfaction_level'>

# %%
plt.figure(figsize=(8,5))

sns.violinplot(x =df['salary'], y =df['satisfaction_level'])
# Out:
# <AxesSubplot:xlabel='salary', ylabel='satisfaction_level'>

# %%
#So now that we have an idea of how to plot visuals together, we're going to create one final visual together. It's called a pair plot.
#This pair plot is going to put together some of the things we've done.

# %%
sns.pairplot(df)

# %%
#It gives us all the different distributions in a scatter. It's not a great view, but the instructor says he just wanted to know that this is possible, that is, that we can view all the correlations within our dataframe, with one co
